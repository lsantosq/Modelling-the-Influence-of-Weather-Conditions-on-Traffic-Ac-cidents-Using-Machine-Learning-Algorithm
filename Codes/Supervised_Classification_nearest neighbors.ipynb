# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.markers
from matplotlib.colors import ListedColormap
from mpl_toolkits import mplot3d
import pandas as pd
from sklearn import datasets,neighbors
from sklearn.neighbors import NearestNeighbors
from sklearn.tree import DecisionTreeClassifier

# %%
#importing data file
incidents=pd.read_csv('Master_Data_clustering_and_regression.csv',encoding='latin1')

# %%
#Supervised Learning- Clustering using KN neighbors
Acc_tot=incidents['Total number of incidents']
Acc_tot_Class=incidents['Class_Total_inc']
temp=incidents['Mean Temp (°C)']
rain=incidents['Total Rain (mm)']
snow=incidents['Total Snow (cm)']
wind=incidents['Spd of Max Gust (km/h)']

#data consilidation
data_tot_acc=np.zeros((948,4))
target_tot_acc=np.zeros(948)

count=0

while count<948:
    data_tot_acc[count,0]=temp[count]
    data_tot_acc[count,1]=rain[count]
    data_tot_acc[count,2]=snow[count]
    data_tot_acc[count,3]=wind[count]
    target_tot_acc[count]=Acc_tot_Class[count]
    count=count+1

#training and testing sets
data_train=data_tot_acc[0:948:2,:]
data_test=data_tot_acc[1:948:2,:]
target_train=target_tot_acc[0:948:2]
target_test=target_tot_acc[1:948:2]

# %%
#Clustering using all attributes
X_data_train=data_train
X_data_test=data_test

# finding optimum number of neighbors-uniform weights
k_all=np.zeros(200)
Accuracy_all=np.zeros(200)
count=0
k=1

while k<201:
    
    clf=neighbors.KNeighborsClassifier(k, weights='uniform')
    clf.fit(X_data_train,target_train)
    Accuracy=clf.score(X_data_test,target_test)
    k_all[count]=k
    Accuracy_all[count]=Accuracy
    k=k+1
    count=count+1

fig, ax=plt.subplots()
plt.grid(linewidth=0.25)
Scatter, =ax.plot(k_all,Accuracy_all*100,'o',label="Accuracy - Uniform Weights", color='red')
ax.set_xlabel('number of neighbors')
ax.set_ylabel('Acuuracy, %')
ax.legend()
plt.show()
print()


# finding optimum number of neighbors-distance weights
k_all=np.zeros(200)
Accuracy_all=np.zeros(200)
count=0
k=1
while k<201:
    
    clf=neighbors.KNeighborsClassifier(k, weights='distance')
    clf.fit(X_data_train,target_train)
    Accuracy=clf.score(X_data_test,target_test)
    k_all[count]=k
    Accuracy_all[count]=Accuracy
    k=k+1
    count=count+1

fig, ax=plt.subplots()
plt.grid(linewidth=0.25)
Scatter, =ax.plot(k_all,Accuracy_all*100,'o',label="Accuracy - Distance Weights", color='blue')
ax.set_xlabel('number of neighbors')
ax.set_ylabel('Acuuracy, %')
ax.legend()
plt.show()

# %%
#Clustering using Temp only

#Data for Temp 
X_data_train=data_train[:,0:1]
X_data_test=data_test[:,0:1]

# finding optimum number of neighbors-uniform weights
k_all=np.zeros(200)
Accuracy_all=np.zeros(200)
count=0
k=1
while k<201:
    
    clf=neighbors.KNeighborsClassifier(k, weights='uniform')
    clf.fit(X_data_train,target_train)
    Accuracy=clf.score(X_data_test,target_test)
    k_all[count]=k
    Accuracy_all[count]=Accuracy
    k=k+1
    count=count+1

fig, ax=plt.subplots()
plt.grid(linewidth=0.25)
Scatter, =ax.plot(k_all,Accuracy_all*100,'o',label="Accuracy - Uniform Weights", color='red')
ax.set_xlabel('number of neighbors')
ax.set_ylabel('Acuuracy, %')
ax.legend()
plt.show()

# finding optimum number of neighbors-distance weights
k_all=np.zeros(200)
Accuracy_all=np.zeros(200)
count=0
k=1
while k<201:
    
    clf=neighbors.KNeighborsClassifier(k, weights='distance')
    clf.fit(X_data_train,target_train)
    Accuracy=clf.score(X_data_test,target_test)
    k_all[count]=k
    Accuracy_all[count]=Accuracy
    k=k+1
    count=count+1

fig, ax=plt.subplots()
plt.grid(linewidth=0.25)
Scatter, =ax.plot(k_all,Accuracy_all*100,'o',label="Accuracy - Distance Weights", color='blue')
ax.set_xlabel('number of neighbors')
ax.set_ylabel('Acuuracy, %')
ax.legend()
plt.show()

# %%
#Data for rain
X_data_train=data_train[:,1:2]
X_data_test=data_test[:,1:2]

# finding optimum number of neighbors-uniform weights
k_all=np.zeros(200)
Accuracy_all=np.zeros(200)
count=0
k=1
while k<201:
    
    clf=neighbors.KNeighborsClassifier(k, weights='uniform')
    clf.fit(X_data_train,target_train)
    Accuracy=clf.score(X_data_test,target_test)
    k_all[count]=k
    Accuracy_all[count]=Accuracy
    k=k+1
    count=count+1

fig, ax=plt.subplots()
plt.grid(linewidth=0.25)
Scatter, =ax.plot(k_all,Accuracy_all*100,'o',label="Accuracy - Uniform Weights", color='red')
ax.set_xlabel('number of neighbors')
ax.set_ylabel('Acuuracy, %')
ax.legend()
plt.show()
print(Accuracy_all)
# finding optimum number of neighbors-distance weights
k_all=np.zeros(200)
Accuracy_all=np.zeros(200)
count=0
k=1
while k<201:
    
    clf=neighbors.KNeighborsClassifier(k, weights='distance')
    clf.fit(X_data_train,target_train)
    Accuracy=clf.score(X_data_test,target_test)
    k_all[count]=k
    Accuracy_all[count]=Accuracy
    k=k+1
    count=count+1

fig, ax=plt.subplots()
plt.grid(linewidth=0.25)
Scatter, =ax.plot(k_all,Accuracy_all*100,'o',label="Accuracy - Distance Weights", color='blue')
ax.set_xlabel('number of neighbors')
ax.set_ylabel('Acuuracy, %')
ax.legend()
plt.show()

print(Accuracy_all)
# Out:
# [0.53164557 0.5443038  0.54008439 0.5443038  0.53586498 0.54008439
#  0.2721519  0.2742616  0.28270042 0.28059072 0.28481013 0.28481013
#  0.55063291 0.55274262 0.55274262 0.55274262 0.55274262 0.55274262
#  0.55274262 0.55274262 0.55274262 0.55274262 0.55274262 0.55274262
#  0.55274262 0.55274262 0.55274262 0.55274262 0.55274262 0.55485232
#  0.55485232 0.55907173 0.55907173 0.55907173 0.55907173 0.55696203
#  0.55696203 0.55696203 0.55696203 0.55696203 0.55696203 0.55696203
#  0.55696203 0.55696203 0.55696203 0.55696203 0.55696203 0.55696203
#  0.55696203 0.55696203 0.55696203 0.55696203 0.55696203 0.55696203
#  0.55696203 0.55696203 0.55696203 0.55696203 0.55696203 0.55696203
#  0.55274262 0.55696203 0.55274262 0.55696203 0.55696203 0.55274262
#  0.55696203 0.55696203 0.55696203 0.55696203 0.55696203 0.55696203
#  0.55696203 0.55696203 0.55696203 0.55696203 0.55696203 0.55696203
#  0.55696203 0.55696203 0.55696203 0.55696203 0.55696203 0.55696203
# ...

# %%
#Data for snow 
X_data_train=data_train[:,2:3]
X_data_test=data_test[:,2:3]

# finding optimum number of neighbors-uniform weights
k_all=np.zeros(200)
Accuracy_all=np.zeros(200)
count=0
k=1
while k<201:
    
    clf=neighbors.KNeighborsClassifier(k, weights='uniform')
    clf.fit(X_data_train,target_train)
    Accuracy=clf.score(X_data_test,target_test)
    k_all[count]=k
    Accuracy_all[count]=Accuracy
    k=k+1
    count=count+1

fig, ax=plt.subplots()
plt.grid(linewidth=0.25)
Scatter, =ax.plot(k_all,Accuracy_all*100,'o',label="Accuracy - Uniform Weights", color='red')
ax.set_xlabel('number of neighbors')
ax.set_ylabel('Acuuracy, %')
ax.legend()
plt.show()
print(Accuracy_all)
# finding optimum number of neighbors-distance weights
k_all=np.zeros(200)
Accuracy_all=np.zeros(200)
count=0
k=1
while k<201:
    
    clf=neighbors.KNeighborsClassifier(k, weights='distance')
    clf.fit(X_data_train,target_train)
    Accuracy=clf.score(X_data_test,target_test)
    k_all[count]=k
    Accuracy_all[count]=Accuracy
    k=k+1
    count=count+1

fig, ax=plt.subplots()
plt.grid(linewidth=0.25)
Scatter, =ax.plot(k_all,Accuracy_all*100,'o',label="Accuracy - Distance Weights", color='blue')
ax.set_xlabel('number of neighbors')
ax.set_ylabel('Acuuracy, %')
ax.legend()
plt.show()
print(Accuracy_all)
# Out:
# [0.55907173 0.56329114 0.18987342 0.56751055 0.18565401 0.18776371
#  0.19198312 0.19831224 0.19831224 0.19831224 0.19831224 0.19831224
#  0.19831224 0.19831224 0.20042194 0.57594937 0.57805907 0.57805907
#  0.56751055 0.57805907 0.57805907 0.57805907 0.56751055 0.56751055
#  0.56751055 0.56751055 0.56751055 0.56751055 0.56751055 0.56751055
#  0.56751055 0.57805907 0.57805907 0.56751055 0.56751055 0.57805907
#  0.57805907 0.57805907 0.57805907 0.57805907 0.57805907 0.56751055
#  0.57805907 0.56751055 0.56751055 0.56751055 0.56751055 0.56751055
#  0.56751055 0.56751055 0.56540084 0.56751055 0.57805907 0.57805907
#  0.58016878 0.58016878 0.58016878 0.57383966 0.57172996 0.57594937
#  0.58016878 0.58016878 0.57383966 0.57383966 0.58016878 0.57383966
#  0.57172996 0.57383966 0.57383966 0.58016878 0.57383966 0.58016878
#  0.57172996 0.57172996 0.57805907 0.57805907 0.58016878 0.57383966
#  0.57383966 0.57172996 0.56751055 0.57383966 0.56751055 0.56751055
# ...

# %%
#Data for wind
X_data_train=data_train[:,3:4]
X_data_test=data_test[:,3:4]

# finding optimum number of neighbors-uniform weights
k_all=np.zeros(200)
Accuracy_all=np.zeros(200)
count=0
k=1
while k<201:
    
    clf=neighbors.KNeighborsClassifier(k, weights='uniform')
    clf.fit(X_data_train,target_train)
    Accuracy=clf.score(X_data_test,target_test)
    k_all[count]=k
    Accuracy_all[count]=Accuracy
    k=k+1
    count=count+1

fig, ax=plt.subplots()
plt.grid(linewidth=0.25)
Scatter, =ax.plot(k_all,Accuracy_all*100,'o',label="Accuracy - Uniform Weights", color='red')
ax.set_xlabel('number of neighbors')
ax.set_ylabel('Acuuracy, %')
ax.legend()
plt.show()
print(Accuracy_all)
# finding optimum number of neighbors-distance weights
k_all=np.zeros(200)
Accuracy_all=np.zeros(200)
count=0
k=1
while k<201:
    
    clf=neighbors.KNeighborsClassifier(k, weights='distance')
    clf.fit(X_data_train,target_train)
    Accuracy=clf.score(X_data_test,target_test)
    k_all[count]=k
    Accuracy_all[count]=Accuracy
    k=k+1
    count=count+1

fig, ax=plt.subplots()
plt.grid(linewidth=0.25)
Scatter, =ax.plot(k_all,Accuracy_all*100,'o',label="Accuracy - Distance Weights", color='blue')
ax.set_xlabel('number of neighbors')
ax.set_ylabel('Acuuracy, %')
ax.legend()
plt.show()
print(Accuracy_all)
# Out:
# [0.34810127 0.43459916 0.46202532 0.44092827 0.4535865  0.47046414
#  0.43459916 0.47046414 0.4535865  0.46202532 0.46202532 0.46202532
#  0.46202532 0.46202532 0.47679325 0.47679325 0.47890295 0.47890295
#  0.47890295 0.47890295 0.47890295 0.47890295 0.47890295 0.47890295
#  0.47890295 0.5021097  0.5021097  0.5021097  0.5021097  0.5021097
#  0.47890295 0.51687764 0.47890295 0.49367089 0.49367089 0.49367089
#  0.51687764 0.51687764 0.51687764 0.51687764 0.51687764 0.51687764
#  0.51687764 0.51687764 0.51687764 0.51687764 0.51687764 0.51687764
#  0.51687764 0.51687764 0.51687764 0.51687764 0.51687764 0.51687764
#  0.51687764 0.51687764 0.51687764 0.51687764 0.51687764 0.51687764
#  0.51687764 0.51687764 0.51687764 0.51687764 0.51687764 0.51687764
#  0.51687764 0.51687764 0.51687764 0.51687764 0.55696203 0.55696203
#  0.55696203 0.51687764 0.51687764 0.51687764 0.51687764 0.51687764
#  0.51687764 0.51687764 0.51687764 0.55696203 0.55696203 0.55696203
# ...

# %%
#Clustering using Temp and snow fall

#Data for Temp and snow fall only
X_data_train=np.concatenate((data_train[:,0:1],data_train[:,2:3]),axis=1)
X_data_test=np.concatenate((data_test[:,0:1],data_test[:,2:3]),axis=1)

# finding optimum number of neighbors-uniform weights
k_all=np.zeros(200)
Accuracy_all=np.zeros(200)
count=0
k=1
while k<201:
    
    clf=neighbors.KNeighborsClassifier(k, weights='uniform')
    clf.fit(X_data_train,target_train)
    Accuracy=clf.score(X_data_test,target_test)
    k_all[count]=k
    Accuracy_all[count]=Accuracy
    k=k+1
    count=count+1

fig, ax=plt.subplots()
plt.grid(linewidth=0.25)
Scatter, =ax.plot(k_all,Accuracy_all*100,'o',label="Accuracy - Uniform Weights", color='red')
ax.set_xlabel('number of neighbors')
ax.set_ylabel('Acuuracy, %')
ax.legend()
plt.show()
print(Accuracy_all)
# finding optimum number of neighbors-distance weights
k_all=np.zeros(200)
Accuracy_all=np.zeros(200)
count=0
k=1
while k<201:
    
    clf=neighbors.KNeighborsClassifier(k, weights='distance')
    clf.fit(X_data_train,target_train)
    Accuracy=clf.score(X_data_test,target_test)
    k_all[count]=k
    Accuracy_all[count]=Accuracy
    k=k+1
    count=count+1

fig, ax=plt.subplots()
plt.grid(linewidth=0.25)
Scatter, =ax.plot(k_all,Accuracy_all*100,'o',label="Accuracy - Distance Weights", color='blue')
ax.set_xlabel('number of neighbors')
ax.set_ylabel('Acuuracy, %')
ax.legend()
plt.show()
print(Accuracy_all)
# Out:
# [0.38818565 0.4978903  0.46624473 0.48101266 0.50421941 0.51054852
#  0.51687764 0.53375527 0.55063291 0.54008439 0.54852321 0.5443038
#  0.57172996 0.58016878 0.56962025 0.58860759 0.58860759 0.57594937
#  0.57172996 0.56118143 0.58016878 0.57172996 0.58438819 0.57594937
#  0.58649789 0.58438819 0.58438819 0.58227848 0.58227848 0.58438819
#  0.58649789 0.58438819 0.58438819 0.58860759 0.58649789 0.58016878
#  0.58227848 0.58438819 0.58227848 0.58016878 0.58016878 0.58438819
#  0.58016878 0.58227848 0.58649789 0.58860759 0.58438819 0.58227848
#  0.58860759 0.58438819 0.58227848 0.58649789 0.58227848 0.58227848
#  0.58227848 0.58016878 0.58438819 0.58227848 0.58438819 0.58438819
#  0.58227848 0.58438819 0.58649789 0.58438819 0.58438819 0.5907173
#  0.5907173  0.5907173  0.592827   0.58649789 0.58860759 0.58860759
#  0.58860759 0.58860759 0.58860759 0.58860759 0.58860759 0.58649789
#  0.58438819 0.58438819 0.58438819 0.58438819 0.58438819 0.58438819
# ...

# %%
#Clustering using Temp and rain fall

#Data for Temp and snow fall only
X_data_train=np.concatenate((data_train[:,0:1],data_train[:,1:2]),axis=1)
X_data_test=np.concatenate((data_test[:,0:1],data_test[:,1:2]),axis=1)

# finding optimum number of neighbors-uniform weights
k_all=np.zeros(200)
Accuracy_all=np.zeros(200)
count=0
k=1
while k<201:
    
    clf=neighbors.KNeighborsClassifier(k, weights='uniform')
    clf.fit(X_data_train,target_train)
    Accuracy=clf.score(X_data_test,target_test)
    k_all[count]=k
    Accuracy_all[count]=Accuracy
    k=k+1
    count=count+1

fig, ax=plt.subplots()
plt.grid(linewidth=0.25)
Scatter, =ax.plot(k_all,Accuracy_all*100,'o',label="Accuracy - Uniform Weights", color='red')
ax.set_xlabel('number of neighbors')
ax.set_ylabel('Acuuracy, %')
ax.legend()
plt.show()
print(Accuracy_all)
# finding optimum number of neighbors-distance weights
k_all=np.zeros(200)
Accuracy_all=np.zeros(200)
count=0
k=1
while k<201:
    
    clf=neighbors.KNeighborsClassifier(k, weights='distance')
    clf.fit(X_data_train,target_train)
    Accuracy=clf.score(X_data_test,target_test)
    k_all[count]=k
    Accuracy_all[count]=Accuracy
    k=k+1
    count=count+1

fig, ax=plt.subplots()
plt.grid(linewidth=0.25)
Scatter, =ax.plot(k_all,Accuracy_all*100,'o',label="Accuracy - Distance Weights", color='blue')
ax.set_xlabel('number of neighbors')
ax.set_ylabel('Acuuracy, %')
ax.legend()
plt.show()
print(Accuracy_all)
# Out:
# [0.43037975 0.53375527 0.5021097  0.48523207 0.51476793 0.51265823
#  0.51898734 0.53797468 0.55485232 0.55907173 0.5443038  0.5443038
#  0.54852321 0.54219409 0.54852321 0.55063291 0.55274262 0.56329114
#  0.55274262 0.56751055 0.56540084 0.57805907 0.57805907 0.57172996
#  0.56751055 0.56751055 0.57805907 0.57383966 0.57172996 0.56962025
#  0.56751055 0.57172996 0.56540084 0.57172996 0.57172996 0.57805907
#  0.57383966 0.57383966 0.57805907 0.57383966 0.57805907 0.57594937
#  0.57594937 0.57172996 0.57594937 0.58016878 0.57594937 0.57805907
#  0.57805907 0.57805907 0.57594937 0.58016878 0.57594937 0.57805907
#  0.58016878 0.58860759 0.58227848 0.58016878 0.58860759 0.58860759
#  0.58649789 0.58649789 0.58860759 0.58860759 0.59493671 0.5907173
#  0.58860759 0.58649789 0.58438819 0.58438819 0.58438819 0.58438819
#  0.58438819 0.58438819 0.58438819 0.58438819 0.58438819 0.58438819
#  0.58438819 0.58438819 0.58438819 0.58438819 0.58438819 0.58438819
# ...

# %%
#Clustering using Temp and wind

#Data for Temp and snow fall only
X_data_train=np.concatenate((data_train[:,0:1],data_train[:,3:4]),axis=1)
X_data_test=np.concatenate((data_test[:,0:1],data_test[:,3:4]),axis=1)

# finding optimum number of neighbors-uniform weights
k_all=np.zeros(200)
Accuracy_all=np.zeros(200)
count=0
k=1
while k<201:
    
    clf=neighbors.KNeighborsClassifier(k, weights='uniform')
    clf.fit(X_data_train,target_train)
    Accuracy=clf.score(X_data_test,target_test)
    k_all[count]=k
    Accuracy_all[count]=Accuracy
    k=k+1
    count=count+1

fig, ax=plt.subplots()
plt.grid(linewidth=0.25)
Scatter, =ax.plot(k_all,Accuracy_all*100,'o',label="Accuracy - Uniform Weights", color='red')
ax.set_xlabel('number of neighbors')
ax.set_ylabel('Acuuracy, %')
ax.legend()
plt.show()
print(Accuracy_all)
# finding optimum number of neighbors-distance weights
k_all=np.zeros(200)
Accuracy_all=np.zeros(200)
count=0
k=1
while k<201:
    
    clf=neighbors.KNeighborsClassifier(k, weights='distance')
    clf.fit(X_data_train,target_train)
    Accuracy=clf.score(X_data_test,target_test)
    k_all[count]=k
    Accuracy_all[count]=Accuracy
    k=k+1
    count=count+1

fig, ax=plt.subplots()
plt.grid(linewidth=0.25)
Scatter, =ax.plot(k_all,Accuracy_all*100,'o',label="Accuracy - Distance Weights", color='blue')
ax.set_xlabel('number of neighbors')
ax.set_ylabel('Acuuracy, %')
ax.legend()
plt.show()
print(Accuracy_all)
# Out:
# [0.40506329 0.48523207 0.45780591 0.48312236 0.5        0.48734177
#  0.51687764 0.51476793 0.52531646 0.52953586 0.53375527 0.53797468
#  0.53586498 0.55485232 0.55063291 0.55063291 0.55907173 0.55696203
#  0.56540084 0.55907173 0.56962025 0.57172996 0.57383966 0.56751055
#  0.57383966 0.57383966 0.58438819 0.57594937 0.58016878 0.58016878
#  0.58438819 0.58649789 0.58649789 0.58227848 0.58227848 0.58227848
#  0.57383966 0.57594937 0.57594937 0.58227848 0.58649789 0.58227848
#  0.58438819 0.58227848 0.57805907 0.58227848 0.57383966 0.57383966
#  0.57594937 0.57172996 0.57172996 0.57383966 0.57172996 0.57172996
#  0.57594937 0.56329114 0.57594937 0.57594937 0.58438819 0.58016878
#  0.58860759 0.58438819 0.58227848 0.58227848 0.58438819 0.58860759
#  0.58438819 0.58227848 0.58227848 0.58016878 0.58016878 0.58227848
#  0.58016878 0.58227848 0.57805907 0.57383966 0.57805907 0.58016878
#  0.57805907 0.58016878 0.58016878 0.57805907 0.58016878 0.57805907
# ...

# %%
#Clustering using snow and wind

#Data for Temp and snow fall only
X_data_train=np.concatenate((data_train[:,2:3],data_train[:,3:4]),axis=1)
X_data_test=np.concatenate((data_test[:,2:3],data_test[:,3:4]),axis=1)

# finding optimum number of neighbors-uniform weights
k_all=np.zeros(200)
Accuracy_all=np.zeros(200)
count=0
k=1
while k<201:
    
    clf=neighbors.KNeighborsClassifier(k, weights='uniform')
    clf.fit(X_data_train,target_train)
    Accuracy=clf.score(X_data_test,target_test)
    k_all[count]=k
    Accuracy_all[count]=Accuracy
    k=k+1
    count=count+1

fig, ax=plt.subplots()
plt.grid(linewidth=0.25)
Scatter, =ax.plot(k_all,Accuracy_all*100,'o',label="Accuracy - Uniform Weights", color='red')
ax.set_xlabel('number of neighbors')
ax.set_ylabel('Acuuracy, %')
ax.legend()
plt.show()
print(Accuracy_all)
# finding optimum number of neighbors-distance weights
k_all=np.zeros(200)
Accuracy_all=np.zeros(200)
count=0
k=1
while k<201:
    
    clf=neighbors.KNeighborsClassifier(k, weights='distance')
    clf.fit(X_data_train,target_train)
    Accuracy=clf.score(X_data_test,target_test)
    k_all[count]=k
    Accuracy_all[count]=Accuracy
    k=k+1
    count=count+1

fig, ax=plt.subplots()
plt.grid(linewidth=0.25)
Scatter, =ax.plot(k_all,Accuracy_all*100,'o',label="Accuracy - Distance Weights", color='blue')
ax.set_xlabel('number of neighbors')
ax.set_ylabel('Acuuracy, %')
ax.legend()
plt.show()
print(Accuracy_all)
# Out:
# [0.38818565 0.44303797 0.4535865  0.46202532 0.44725738 0.48312236
#  0.44725738 0.5        0.48945148 0.46835443 0.47046414 0.47046414
#  0.48523207 0.50421941 0.55274262 0.55063291 0.56751055 0.56962025
#  0.55907173 0.57172996 0.57383966 0.57594937 0.57383966 0.57172996
#  0.57594937 0.57594937 0.57594937 0.57805907 0.57805907 0.57594937
#  0.57383966 0.57172996 0.56751055 0.56751055 0.56751055 0.56962025
#  0.57383966 0.56329114 0.56540084 0.52742616 0.52742616 0.56962025
#  0.52531646 0.52531646 0.52742616 0.52953586 0.56329114 0.56540084
#  0.56751055 0.55907173 0.56118143 0.55696203 0.56118143 0.56329114
#  0.56118143 0.56329114 0.56118143 0.56118143 0.56118143 0.56118143
#  0.56118143 0.56118143 0.55696203 0.55696203 0.55696203 0.56118143
#  0.55907173 0.55696203 0.55485232 0.55485232 0.55485232 0.55485232
#  0.55485232 0.55485232 0.55485232 0.55485232 0.55485232 0.55485232
#  0.55485232 0.55485232 0.55485232 0.55696203 0.55696203 0.55907173
# ...

# %%
#Clustering using rain and wind

#Data for Temp and snow fall only
X_data_train=np.concatenate((data_train[:,1:2],data_train[:,3:4]),axis=1)
X_data_test=np.concatenate((data_test[:,1:2],data_test[:,3:4]),axis=1)

# finding optimum number of neighbors-uniform weights
k_all=np.zeros(200)
Accuracy_all=np.zeros(200)
count=0
k=1
while k<201:
    
    clf=neighbors.KNeighborsClassifier(k, weights='uniform')
    clf.fit(X_data_train,target_train)
    Accuracy=clf.score(X_data_test,target_test)
    k_all[count]=k
    Accuracy_all[count]=Accuracy
    k=k+1
    count=count+1

fig, ax=plt.subplots()
plt.grid(linewidth=0.25)
Scatter, =ax.plot(k_all,Accuracy_all*100,'o',label="Accuracy - Uniform Weights", color='red')
ax.set_xlabel('number of neighbors')
ax.set_ylabel('Acuuracy, %')
ax.legend()
plt.show()
print(Accuracy_all)
# finding optimum number of neighbors-distance weights
k_all=np.zeros(200)
Accuracy_all=np.zeros(200)
count=0
k=1
while k<201:
    
    clf=neighbors.KNeighborsClassifier(k, weights='distance')
    clf.fit(X_data_train,target_train)
    Accuracy=clf.score(X_data_test,target_test)
    k_all[count]=k
    Accuracy_all[count]=Accuracy
    k=k+1
    count=count+1

fig, ax=plt.subplots()
plt.grid(linewidth=0.25)
Scatter, =ax.plot(k_all,Accuracy_all*100,'o',label="Accuracy - Distance Weights", color='blue')
ax.set_xlabel('number of neighbors')
ax.set_ylabel('Acuuracy, %')
ax.legend()
plt.show()
print(Accuracy_all)
# Out:
# [0.38396624 0.49156118 0.51265823 0.44092827 0.47679325 0.47679325
#  0.47679325 0.5021097  0.46624473 0.46835443 0.4978903  0.47046414
#  0.46624473 0.47257384 0.47257384 0.46624473 0.47257384 0.48734177
#  0.48734177 0.48734177 0.48734177 0.49578059 0.49578059 0.49367089
#  0.49367089 0.49367089 0.49367089 0.49156118 0.49578059 0.49367089
#  0.49367089 0.49578059 0.4978903  0.4978903  0.4978903  0.4978903
#  0.4978903  0.4978903  0.4978903  0.49578059 0.49578059 0.49367089
#  0.51054852 0.49578059 0.51476793 0.4978903  0.5        0.5
#  0.5        0.4978903  0.53797468 0.55274262 0.55485232 0.51687764
#  0.51687764 0.51898734 0.51898734 0.55696203 0.55696203 0.55696203
#  0.55696203 0.55696203 0.55696203 0.55696203 0.55696203 0.55485232
#  0.55485232 0.55485232 0.55485232 0.55485232 0.55485232 0.55485232
#  0.55485232 0.55485232 0.55485232 0.55485232 0.55485232 0.55485232
#  0.51687764 0.51687764 0.51687764 0.51687764 0.51687764 0.51687764
# ...
